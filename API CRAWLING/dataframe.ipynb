# %%
import pandas as pd
import numpy as np

#import matplotlib.pyplot as plt
#import seaborn as sns
df = pd.read_csv('output\youtube_trending_US_20250327_001444.csv')
df.info()
df.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   videoId      50 non-null     object
#  1   title        50 non-null     object
#  2   channel      50 non-null     object
#  3   publishedAt  50 non-null     object
#  4   views        50 non-null     int64
#  5   likes        50 non-null     int64
#  6   comments     50 non-null     int64
#  7   duration     50 non-null     object
# dtypes: int64(3), object(5)
# memory usage: 3.3+ KB
# <>:6: SyntaxWarning: invalid escape sequence '\y'
# <>:6: SyntaxWarning: invalid escape sequence '\y'
# C:\Users\Windows\AppData\Local\Temp\ipykernel_76852\3119701971.py:6: SyntaxWarning: invalid escape sequence '\y'
#   df = pd.read_csv('output\youtube_trending_US_20250327_001444.csv')
#        videoId                                              title  \
# ...

# %%
df = pd.read_csv('youtube_trending_US_20250326_223742.csv')
df.info()
df.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   videoId       50 non-null     object
#  1   title         50 non-null     object
#  2   channelTitle  50 non-null     object
#  3   publishedAt   50 non-null     object
#  4   viewCount     50 non-null     int64
#  5   likeCount     50 non-null     int64
#  6   commentCount  50 non-null     int64
#  7   tags          41 non-null     object
#  8   description   50 non-null     object
#  9   categoryId    50 non-null     int64
#  10  duration      50 non-null     object
# dtypes: int64(4), object(7)
# memory usage: 4.4+ KB
#        videoId                                              title  \
# 0  UWMzKXsY9A4    Final Destination Bloodlines | Official Trailer
# 1  zX1vB0K4Q5s  Argentina vs Brasil | Highlights Rumbo al Mund...
# ...
